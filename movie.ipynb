# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('./data/movie.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movies.describe(include=float).T
# Out:
#                           count          mean           std      min  \
# num_critic_for_reviews   4867.0  1.379889e+02  1.202394e+02     1.00
# duration                 4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes  4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes   4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes   4909.0  6.494488e+03  1.510699e+04     0.00
# gross                    4054.0  4.764451e+07  6.737255e+07   162.00
# facenumber_in_poster     4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews     4895.0  2.676688e+02  3.729348e+02     1.00
# budget                   4432.0  3.654749e+07  1.002427e+08   218.00
# title_year               4810.0  2.002448e+03  1.245398e+01  1916.00
# actor_2_facebook_likes   4903.0  1.621924e+03  4.011300e+03     0.00
# imdb_score               4916.0  6.437429e+00  1.127802e+00     1.60
# aspect_ratio             4590.0  2.222349e+00  1.402940e+00     1.18
#
# ...

# %%
np.finfo('float64')
# Out:
# finfo(resolution=1e-15, min=-1.7976931348623157e+308, max=1.7976931348623157e+308, dtype=float64)

# %%
np.finfo('float32')
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)

# %%
np.finfo('float16')
# Out:
# finfo(resolution=0.001, min=-6.55040e+04, max=6.55040e+04, dtype=float16)

# %%
movies2 = pd.read_csv('./data/movie.csv',
                    dtype= {
                        'num_critic_for_reviews': np.float32,
                        'duration': np.float32,
                        'director_facebook_likes': np.float32,
                        'actor_3_facebook_likes': np.float32,
                        'actor_1_facebook_likes': np.float32,
                        'gross': np.float32,
                        'facenumber_in_poster': np.float32,
                        'num_user_for_reviews': np.float32,
                        'budget': np.float32,
                        'title_year': np.float32,
                        'actor_2_facebook_likes': np.float32,
                        'imdb_score': np.float32,
                        'aspect_ratio': np.float32,
                    })
movies2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float32
#  3   duration                   4901 non-null   float32
#  4   director_facebook_likes    4814 non-null   float32
#  5   actor_3_facebook_likes     4893 non-null   float32
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float32
#  8   gross                      4054 non-null   float32
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
intCol = ['num_voted_users', 'cast_total_facebook_likes', 'movie_facebook_likes']
movies.loc[:, intCol].describe().T
# Out:
#                             count          mean            std  min      25%  \
# num_voted_users            4916.0  82644.924939  138322.162547  5.0  8361.75
# cast_total_facebook_likes  4916.0   9579.815907   18164.316990  0.0  1394.75
# movie_facebook_likes       4916.0   7348.294142   19206.016458  0.0     0.00
#
#                                50%       75%        max
# num_voted_users            33132.5  93772.75  1689764.0
# cast_total_facebook_likes   3049.0  13616.75   656730.0
# movie_facebook_likes         159.0   2000.00   349000.0

# %%
np.iinfo('int64')
# Out:
# iinfo(min=-9223372036854775808, max=9223372036854775807, dtype=int64)

# %%
np.iinfo('int32')
# Out:
# iinfo(min=-2147483648, max=2147483647, dtype=int32)

# %%
np.iinfo('int16')
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
movies3 = pd.read_csv('./data/movie.csv',
                    dtype= {
                        'num_critic_for_reviews': np.float32,
                        'duration': np.float32,
                        'director_facebook_likes': np.float32,
                        'actor_3_facebook_likes': np.float32,
                        'actor_1_facebook_likes': np.float32,
                        'gross': np.float32,
                        'facenumber_in_poster': np.float32,
                        'num_user_for_reviews': np.float32,
                        'budget': np.float32,
                        'title_year': np.float32,
                        'actor_2_facebook_likes': np.float32,
                        'imdb_score': np.float32,
                        'aspect_ratio': np.float32,
                        'num_voted_users': np.int32,
                        'cast_total_facebook_likes': np.int32,
                        'movie_facebook_likes': np.int32
                    })
movies3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float32
#  3   duration                   4901 non-null   float32
#  4   director_facebook_likes    4814 non-null   float32
#  5   actor_3_facebook_likes     4893 non-null   float32
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float32
#  8   gross                      4054 non-null   float32
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int32
# ...

# %%
movies.describe(include='O').T
# Out:
#                 count unique  \
# color            4897      2
# director_name    4814   2397
# actor_2_name     4903   3030
# genres           4916    914
# actor_1_name     4909   2095
# movie_title      4916   4916
# actor_3_name     4893   3519
# plot_keywords    4764   4756
# movie_imdb_link  4916   4916
# language         4904     47
# country          4911     65
# content_rating   4616     18
#
#                                                                top  freq
# color                                                        Color  4693
# director_name                                     Steven Spielberg    26
# actor_2_name                                        Morgan Freeman    18
# genres                                                       Drama   233
# actor_1_name                                        Robert De Niro    48
# movie_title               Cats & Dogs: The Revenge of Kitty Galore     1
# ...

# %%
movies.color.value_counts()
# Out:
# Color              4693
# Black and White     204
# Name: color, dtype: int64

# %%
movies.language.value_counts()
# Out:
# English       4582
# French          73
# Spanish         40
# Hindi           28
# Mandarin        24
# German          19
# Japanese        17
# Cantonese       11
# Russian         11
# Italian         11
# Portuguese       8
# Korean           7
# Arabic           5
# Swedish          5
# Hebrew           5
# Danish           5
# Persian          4
# Norwegian        4
# Dutch            4
# Polish           3
# Thai             3
# Chinese          3
# Indonesian       2
# Icelandic        2
# Romanian         2
# Zulu             2
# Dari             2
# Aboriginal       2
# None             2
# Swahili          1
# Dzongkha         1
# Kazakh           1
# Czech            1
# Greek            1
# Slovenian        1
# Panjabi          1
# Aramaic          1
# Telugu           1
# Urdu             1
# Bosnian          1
# Kannada          1
# Tamil            1
# Filipino         1
# Maya             1
# Mongolian        1
# Vietnamese       1
# Hungarian        1
# ...

# %%
movies.country.value_counts()
# Out:
# USA                   3710
# UK                     434
# France                 154
# Canada                 124
# Germany                 94
#                       ...
# Slovenia                 1
# Dominican Republic       1
# Panama                   1
# Official site            1
# Georgia                  1
# Name: country, Length: 65, dtype: int64

# %%
movies.content_rating.value_counts()
# Out:
# R            2067
# PG-13        1411
# PG            686
# Not Rated     115
# G             112
# Unrated        59
# Approved       54
# TV-14          30
# TV-MA          18
# TV-PG          13
# X              12
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y7           1
# TV-Y            1
# Name: content_rating, dtype: int64

# %%
movies4 = pd.read_csv('./data/movie.csv',
                    dtype= {
                        'num_critic_for_reviews': np.float32,
                        'duration': np.float32,
                        'director_facebook_likes': np.float32,
                        'actor_3_facebook_likes': np.float32,
                        'actor_1_facebook_likes': np.float32,
                        'gross': np.float32,
                        'facenumber_in_poster': np.float32,
                        'num_user_for_reviews': np.float32,
                        'budget': np.float32,
                        'title_year': np.float32,
                        'actor_2_facebook_likes': np.float32,
                        'imdb_score': np.float32,
                        'aspect_ratio': np.float32,
                        'num_voted_users': np.int32,
                        'cast_total_facebook_likes': np.int32,
                        'movie_facebook_likes': np.int32,
                        'color': 'category',
                        'language': 'category',
                        'country': 'category',
                        'content_rating': 'category',
                    })
movies4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   category
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float32
#  3   duration                   4901 non-null   float32
#  4   director_facebook_likes    4814 non-null   float32
#  5   actor_3_facebook_likes     4893 non-null   float32
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float32
#  8   gross                      4054 non-null   float32
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int32
# ...

# %%
movies4.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505856.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# genres 원핫인코딩
