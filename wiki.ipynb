# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/SpaceX'
dfs = pd.read_html(url)
len(dfs)
# Out:
# 23

# %%
dfs[3]
# Out:
#                  Date                                        Achievement  \
# 0   28 September 2008  First privately funded fully liquid-fueled roc...
# 1        14 July 2009  First privately developed liquid-fueled rocket...
# 2     9 December 2010  First private company to successfully launch, ...
# 3         25 May 2012  First private company to send a spacecraft to ...
# 4    22 December 2015  First landing of an orbital-class rocket's fir...
# 5        8 April 2016  First landing of an orbital-class rocket's fir...
# 6       30 March 2017  First reuse, reflight and (second) landing of ...
# 7       30 March 2017  First controlled flyback and recovery of a pay...
# 8         3 June 2017  First re-flight of a commercial cargo spacecra...
# 9     6 February 2018  First private spacecraft launched into helioce...
# 10       2 March 2019  First private company to send a human-rated sp...
# 11       3 March 2019  First private company to autonomously dock a c...
# ...
